# %%
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from rubin_scheduler.utils import calc_season, hpid2_ra_dec
import healpy as hp
import numpy as np

# %%
nside=128
hpids = np.arange(hp.nside2npix(nside))
ra, dec = hpid2_ra_dec(nside, hpids)

# %%
hp.mollview(ra)

# %%
mjd = 60000
seasons = calc_season(ra, mjd)
hp.mollview(seasons, unit="season", title="MJD = %i" % mjd)
